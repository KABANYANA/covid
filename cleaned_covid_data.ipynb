# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib as plt

# %%
df=pd.read_csv('covid.csv')
df
# Out:
#       Unnamed: 0  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0            223        643      18         30     595         95           1
# 1            410        920      26         36     858        277           8
# 2            597       1406      42         39    1325        486          16
# 3            784       2075      56         49    1970        669          14
# 4            971       2877      82         58    2737        802          26
# ...          ...        ...     ...        ...     ...        ...         ...
# 8814       35148      21209     121      11674    9414        678           5
# 8815       35149      15988     146       9959    5883        525           4
# 8816       35153       1691     483        833     375         10           4
# 8817       35154       4552     140       2815    1597         71           1
# 8818       35155       2704      36        542    2126        192           2
#
#       New recovered
# 0                 2
# 1                 6
# 2                 3
# 3                10
# 4                 9
# ...             ...
# 8814            569
# 8815            213
# 8816             36
# 8817            465
# 8818             24
#
# [8819 rows x 8 columns]

# %%
columns_to_drop = ['Unnamed: 0']

# %%
df= df.drop(columns_to_drop, axis=1)

# %%
df
# Out:
#       Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0           643      18         30     595         95           1
# 1           920      26         36     858        277           8
# 2          1406      42         39    1325        486          16
# 3          2075      56         49    1970        669          14
# 4          2877      82         58    2737        802          26
# ...         ...     ...        ...     ...        ...         ...
# 8814      21209     121      11674    9414        678           5
# 8815      15988     146       9959    5883        525           4
# 8816       1691     483        833     375         10           4
# 8817       4552     140       2815    1597         71           1
# 8818       2704      36        542    2126        192           2
#
#       New recovered
# 0                 2
# 1                 6
# 2                 3
# 3                10
# 4                 9
# ...             ...
# 8814            569
# 8815            213
# 8816             36
# 8817            465
# 8818             24
#
# [8819 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Confirmed        0
# Deaths           0
# Recovered        0
# Active           0
# New cases        0
# New deaths       0
# New recovered    0
# dtype: int64

# %%
df.dtypes
# Out:
# Confirmed        int64
# Deaths           int64
# Recovered        int64
# Active           int64
# New cases        int64
# New deaths       int64
# New recovered    int64
# dtype: object

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#       Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0           643      18         30     595         95           1
# 1           920      26         36     858        277           8
# 2          1406      42         39    1325        486          16
# 3          2075      56         49    1970        669          14
# 4          2877      82         58    2737        802          26
# ...         ...     ...        ...     ...        ...         ...
# 8814      21209     121      11674    9414        678           5
# 8815      15988     146       9959    5883        525           4
# 8816       1691     483        833     375         10           4
# 8817       4552     140       2815    1597         71           1
# 8818       2704      36        542    2126        192           2
#
#       New recovered
# 0                 2
# 1                 6
# 2                 3
# 3                10
# 4                 9
# ...             ...
# 8814            569
# 8815            213
# 8816             36
# 8817            465
# 8818             24
#
# [8819 rows x 7 columns]

# %%
df.to_csv('covid_clean.csv')
